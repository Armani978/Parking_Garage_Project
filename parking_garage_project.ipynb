# %% [markdown]
# # Parking Garage Project
#
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
# Your parking gargage class should have the following methods:
# - takeTicket
#    - This should decrease the amount of tickets available by 1
#    - This should decrease the amount of parkingSpaces available by 1
# - payForParking
#    - Display an input that waits for an amount from the user and store it in a variable
#    - If the payment variable is not empty then ->  display a message to the user that their ticket has been paid and they have 15mins to leave
#    - This should update the "currentTicket" dictionary key "paid" to True
# - leaveGarage
#    - If the ticket has been paid, display a message of "Thank You, have a nice day"
#    - If the ticket has not been paid, display an input prompt for payment
#       - Once paid, display message "Thank you, have a nice day!"
#    - Update parkingSpaces list to increase by 1
#    - Update tickets list to increase by 1
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary

# %%
class parking_Garage():
    def __init__(self):
        self.ticket = [1, 2, 3, 4, 5, 6]
        self.parkingSpaces = [1, 2, 3, 4, 5, 6]
        self.currentTicket = {}


# ----------------------TAKE TICKET--------------------------

    
    def takeTicket(self):
        print("Welcome to Armani's Parking Garage")
        while True:
            print(f'{self.currentTicket}')
            print(f'{self.ticket}')
            if self.ticket == "":
                    print("Garage is full")
                    break
            tickets = input("Take ticket. Type T to take ticket ")
            if tickets.lower() == 't':
                if self.ticket[0] == 1:
                    self.currentTicket.update({1:""})
                    self.ticket.pop()

                elif self.ticket[0] == 2:
                    self.currentTicket.update({2:""})
                    self.ticket.pop()

                elif self.ticket[0] == 3:
                    self.currentTicket.update({3:""})
                    self.ticket.pop()

                elif self.ticket[0] == 4:
                    self.currentTicket.update({4:""})
                    self.ticket.pop()

                elif self.ticket[0] == 5:
                    self.currentTicket.update({5:""})
                
                print(f'{self.ticket}')

                print(f"Here is ticket: {self.ticket[0]}")
                
                self.options()
                

            else:
                print("Garage is full")
                break

# ----------------------OPTIONS--------------------------

    def options(self):
        while True:
            print(f'{self.currentTicket}')
            options_var = input("Do you want to pay, park or leave? pay/park/leave")
            if options_var.lower()== 'pay':
                self.payForParking()
                    
            elif options_var.lower() == 'park':
                if len(self.parkingSpaces)<=0:
                    print("Garage is full")
                    break
                
                if self.parkingSpaces[-1] == 6:
                    self.currentTicket.update({1:""})
                    self.parkingSpaces.pop()
                    self.ticket.pop()
                    print("Have a nice day!")

                elif self.parkingSpaces[-1] == 5:
                    self.currentTicket.update({2:""})
                    self.parkingSpaces.pop()
                    self.ticket.pop()
                    print("Have a nice day!")

                elif self.parkingSpaces[-1] == 4:
                    self.currentTicket.update({3:""})
                    self.parkingSpaces.pop()
                    self.ticket.pop()
                    print("Have a nice day!")

                elif self.parkingSpaces[-1] == 3:
                    self.currentTicket.update({4:""})
                    self.parkingSpaces.pop()
                    self.ticket.pop()
                    print("Have a nice day!")

                elif self.parkingSpaces[-1] == 2:
                    self.currentTicket.update({5:""})
                    self.parkingSpaces.pop()
                    self.ticket.pop()
                    print("Have a nice day!")

                elif self.parkingSpaces[-1]==1:
                    self.currentTicket.update({6:""})
                    self.parkingSpaces.pop()
                    
                    print("Have a nice day!")

                else:
                    print("Garage is full!")
                print(self.parkingSpaces)
                
            else:
                self.leaveGarage()        



# ----------------------PAY FOR PARKING--------------------------

    def payForParking(self):
        while True:

            print(f'{self.currentTicket}')
            var = input("Pay for a parking space, Type in 1 to pay : ")

            
            
            if int(var) <= 1:
                if self.parkingSpaces[-1] == 6:
                    self.currentTicket.update({1:"paid"})
                    self.parkingSpaces.pop()
                    print("Have a nice day!")

                elif self.parkingSpaces[-1] == 5:
                    self.currentTicket.update({2:"paid"})
                    self.parkingSpaces.pop()
                    print("Have a nice day!")

                elif self.parkingSpaces[-1] == 4:
                    self.currentTicket.update({3:"paid"})
                    self.parkingSpaces.pop()
                    print("Have a nice day!")

                elif self.parkingSpaces[-1] == 3:
                    self.currentTicket.update({4:"paid"})
                    self.parkingSpaces.pop()
                    print("Have a nice day!")

                elif self.parkingSpaces[-1] == 2:
                    self.currentTicket.update({5:"paid"})
                    self.parkingSpaces.pop()
                    print("Have a nice day!")

                else:
                    self.currentTicket.update({6:"paid"})
                    self.parkingSpaces.pop()
                    print("Have a nice day!")

                print("Your ticket has been paid and valet will park your car for you")
                
                print(f'{self.parkingSpaces}')
                self.options()
            
            else:
                break

# ----------------------LEAVE GARAGE--------------------------       

    def leaveGarage(self):
        while True:
            scanticket = input("Please scan your ticket: ")
            if scanticket == '1':
                if 'paid' in self.currentTicket.get(1, 'paid'):
                    print("Have a nice day!")
                    
                    self.parkingSpaces.append(6)
                    self.ticket.append(6)
                    self.currentTicket.pop(1)
                    self.takeTicket()
                else:
                    print("Pay for ticket!")
                    self.payForParking()    
            if scanticket == '2':
                if 'paid' in self.currentTicket.get(1, 'paid'):
                    print("Have a nice day!")
                    
                    self.parkingSpaces.append(5)
                    self.ticket.append(5)
                    self.currentTicket.pop(2)
                    self.takeTicket()
                else:
                    print("Pay for ticket!")
                    self.payForParking() 

            if scanticket == '3':

                if 'paid' in self.currenpaytTicket.get(1, 'paid'):
                    print("Have a nice day!")
                    
                    self.parkingSpaces.append(4)
                    self.ticket.append(4)
                    self.currentTicket.pop(3)
                    self.takeTicket()

                else:
                    print("Pay for ticket!")
                    self.payForParking()         
            else:
                print("ERROR")    
            
park = parking_Garage()    
park.takeTicket()
# Out:
# Welcome to Armani's Parking Garage
# {}
# [1, 2, 3, 4, 5, 6]
# Take ticket. Type T to take ticket T
# [1, 2, 3, 4, 5]
# Here is ticket: 1
# {1: ''}
# Do you want to pay, park or leave? pay/park/leavepay
# {1: ''}
# Pay for a parking space, Type in 1 to pay : 1
# Have a nice day!
# Your ticket has been paid and valet will park your car for you
# [1, 2, 3, 4, 5]
# {1: 'paid'}
# Do you want to pay, park or leave? pay/park/leaveleave
# Please scan your ticket: 1
# Have a nice day!
# Welcome to Armani's Parking Garage
# {}
# [1, 2, 3, 4, 5, 6]
